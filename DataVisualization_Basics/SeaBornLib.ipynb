# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Automobile_data.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
sns.countplot(df['body-style']) #Coutnplot graph is for categorical data only
# Out:
# <Axes: xlabel='count', ylabel='body-style'>

# %%
df['body-style'].value_counts() #returned frequency
# Out:
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
df['make'].nunique() #unique values in make column
# Out:
# 22

# %%
#Set them and style for graph
sns.set_theme(style='darkgrid', palette='rainbow')

# %%
sns.countplot(y= 'make',data=df)
#plt.show()
# Out:
# <Axes: xlabel='count', ylabel='make'>

# %%
sns.countplot(data=df, x='body-style', hue='fuel-type') #it only accepts value on x asis, hue paramenter use for comaprision like which car use which fuel
# Out:
# <Axes: xlabel='body-style', ylabel='count'>

# %%
#Distribution plots (Skewness , outliers)
sns.histplot(df['curb-weight'])
plt.show()

# %%
sns.distplot(df['curb-weight'])
# Out:
# <Axes: xlabel='curb-weight', ylabel='Density'>

# %%
#KDE:- kernel density estimation plot for curve graph output
sns.kdeplot(df['curb-weight'])
# Out:
# <Axes: xlabel='curb-weight', ylabel='Density'>
